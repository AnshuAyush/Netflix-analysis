# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
raw_df = pd.read_csv("netflix_titles.csv")

# %%
raw_df = raw_df.drop(columns = "show_id")

# %%
movie = 0
series = 0
for i in range(7787):
    if (raw_df["type"][i] == "Movie"):
        movie += 1
    elif (raw_df["type"][i] == "TV Show"):
        series += 1

# %%
(movie / 7787) * 100
# Out:
# 69.05098240657506

# %%
print(series)
print(movie)
# Out:
# 2410
# 5377

# %%
data = {'Movies': 5377 , 'TV Show':2410}
No_of_user = list(data.keys())
values = list(data.values())
plt.ylabel("No of user")
plt.xlabel("Genere")
plt.bar(No_of_user , values , color = "maroon" , width = 0.6 , )
# Out:
# <BarContainer object of 2 artists>

# %% [markdown]
# # As per data Netflix users likes to watch movies more than TV show

# %%
raw_df
# Out:
#          type                                    title           director  \
# 0     TV Show                                       3%                NaN
# 1       Movie                                     7:19  Jorge Michel Grau
# 2       Movie                                    23:59       Gilbert Chan
# 3       Movie                                        9        Shane Acker
# 4       Movie                                       21     Robert Luketic
# ...       ...                                      ...                ...
# 7782    Movie                                     Zozo        Josef Fares
# 7783    Movie                                   Zubaan        Mozez Singh
# 7784    Movie                        Zulu Man in Japan                NaN
# 7785  TV Show                    Zumbo's Just Desserts                NaN
# 7786    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS           Sam Dunn
#
#                                                    cast  \
# ...

# %%
df = raw_df.dropna()
df
# Out:
#          type       title           director  \
# 1       Movie        7:19  Jorge Michel Grau
# 2       Movie       23:59       Gilbert Chan
# 3       Movie           9        Shane Acker
# 4       Movie          21     Robert Luketic
# 5     TV Show          46        Serdar Akar
# ...       ...         ...                ...
# 7778    Movie  Zombieland    Ruben Fleischer
# 7780    Movie         Zoo       Shlok Sharma
# 7781    Movie        Zoom       Peter Hewitt
# 7782    Movie        Zozo        Josef Fares
# 7783    Movie      Zubaan        Mozez Singh
#
#                                                    cast  \
# 1     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2     Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3     Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# 5     Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...
# ...                                                 ...
# ...

# %%
df.isnull().any()
# Out:
# type            False
# title           False
# director        False
# cast            False
# country         False
# date_added      False
# release_year    False
# rating          False
# duration        False
# listed_in       False
# description     False
# dtype: bool

# %%
df
# Out:
#          type       title           director  \
# 1       Movie        7:19  Jorge Michel Grau
# 2       Movie       23:59       Gilbert Chan
# 3       Movie           9        Shane Acker
# 4       Movie          21     Robert Luketic
# 5     TV Show          46        Serdar Akar
# ...       ...         ...                ...
# 7778    Movie  Zombieland    Ruben Fleischer
# 7780    Movie         Zoo       Shlok Sharma
# 7781    Movie        Zoom       Peter Hewitt
# 7782    Movie        Zozo        Josef Fares
# 7783    Movie      Zubaan        Mozez Singh
#
#                                                    cast  \
# 1     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2     Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3     Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# 5     Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...
# ...                                                 ...
# ...

# %%
len(df["director"]) == len(df["cast"])
# Out:
# True

# %%
df.shape
# Out:
# (4808, 11)

# %%
len(df["director"])
# Out:
# 4808

# %%
df.dropna()
# Out:
#          type       title           director  \
# 1       Movie        7:19  Jorge Michel Grau
# 2       Movie       23:59       Gilbert Chan
# 3       Movie           9        Shane Acker
# 4       Movie          21     Robert Luketic
# 5     TV Show          46        Serdar Akar
# ...       ...         ...                ...
# 7778    Movie  Zombieland    Ruben Fleischer
# 7780    Movie         Zoo       Shlok Sharma
# 7781    Movie        Zoom       Peter Hewitt
# 7782    Movie        Zozo        Josef Fares
# 7783    Movie      Zubaan        Mozez Singh
#
#                                                    cast  \
# 1     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2     Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3     Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# 5     Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...
# ...                                                 ...
# ...

# %%
df.dropna()
# Out:
#          type       title           director  \
# 1       Movie        7:19  Jorge Michel Grau
# 2       Movie       23:59       Gilbert Chan
# 3       Movie           9        Shane Acker
# 4       Movie          21     Robert Luketic
# 5     TV Show          46        Serdar Akar
# ...       ...         ...                ...
# 7778    Movie  Zombieland    Ruben Fleischer
# 7780    Movie         Zoo       Shlok Sharma
# 7781    Movie        Zoom       Peter Hewitt
# 7782    Movie        Zozo        Josef Fares
# 7783    Movie      Zubaan        Mozez Singh
#
#                                                    cast  \
# 1     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2     Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3     Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# 5     Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...
# ...                                                 ...
# ...

# %%
df = pd.DataFrame(df , index = range(1 , 2928))

# %%
df.dropna()
# Out:
#          type                           title                    director  \
# 1       Movie                            7:19           Jorge Michel Grau
# 2       Movie                           23:59                Gilbert Chan
# 3       Movie                               9                 Shane Acker
# 4       Movie                              21              Robert Luketic
# 5     TV Show                              46                 Serdar Akar
# ...       ...                             ...                         ...
# 2921    Movie        I'll Sleep When I'm Dead                Justin Krook
# 2922    Movie                 I'm Brent Morin                 Lance Bangs
# 2923    Movie  I'm in Love with a Church Girl                  Steve Race
# 2925    Movie              I'm No Longer Here  Fernando Frías de la Parra
# 2927    Movie   I'm Thinking of Ending Things             Charlie Kaufman
#
#                                                    cast  \
# ...

# %%
df = raw_df.dropna()

# %%
df =df.reset_index(drop = True)

# %%
df
# Out:
#          type       title           director  \
# 0       Movie        7:19  Jorge Michel Grau
# 1       Movie       23:59       Gilbert Chan
# 2       Movie           9        Shane Acker
# 3       Movie          21     Robert Luketic
# 4     TV Show          46        Serdar Akar
# ...       ...         ...                ...
# 4803    Movie  Zombieland    Ruben Fleischer
# 4804    Movie         Zoo       Shlok Sharma
# 4805    Movie        Zoom       Peter Hewitt
# 4806    Movie        Zozo        Josef Fares
# 4807    Movie      Zubaan        Mozez Singh
#
#                                                    cast  \
# 0     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 1     Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 2     Elijah Wood, John C. Reilly, Jennifer Connelly...
# 3     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# 4     Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...
# ...                                                 ...
# ...

# %%
india_count = 0

for i in range(4808):
    if df["country"][i] == "India":
        india_count += 1
india_count
# Out:
# 832

# %%
US_count = 0

for i in range(4808):
    if df["country"][i] == "United States":
        US_count += 1
US_count
# Out:
# 1653

# %%
Turkey_count= 0

for i in range(4808):
    if df["country"][i] == "Turkey":
        Turkey_count += 1
Turkey_count
# Out:
# 76

# %%
maxico_count = 0
for i in range(4808):
    if df["country"][i] == "Mexico":
        maxico_count += 1
maxico_count
# Out:
# 59

# %%
singapore_count = 0
for i in range(4808):
    if df["country"][i] == "Singapore":
        singapore_count += 1
singapore_count
# Out:
# 6

# %%
UK_count = 0
for i in range(4808):
    if df["country"][i] == "United Kingdom":
        UK_count += 1
UK_count
# Out:
# 174

# %%
Japan_count = 0
for i in range(4808):
    if df["country"][i] == "Japan":
        Japan_count += 1
Japan_count
# Out:
# 76

# %%
Australia_count = 0
for i in range(4808):
    if df["country"][i] == "Australia":
        UK_count += 1
Australia_count
# Out:
# 0

# %%
Thailand_count = 0 
for i in range(4808):
    if df["country"][i] == "Thailand":
        Thailand_count += 1
    
Thailand_count
# Out:
# 37

# %%
data = {"India":india_count , "Turkey": Turkey_count , "US": US_count , "Mexico":maxico_count , 
        "Singapo":singapore_count , "UK":UK_count, "Aus":Australia_count, "Japan": Japan_count , 
        "Thailand":Thailand_count }
values = list(data.values())
keys = list(data.keys())
plt.bar(keys , values , color = "teal" , width = 0.8)
# Out:
# <BarContainer object of 9 artists>

# %% [markdown]
# # USA releases the maximum no of movies on netflix

# %%
df
# Out:
#          type       title           director  \
# 0       Movie        7:19  Jorge Michel Grau
# 1       Movie       23:59       Gilbert Chan
# 2       Movie           9        Shane Acker
# 3       Movie          21     Robert Luketic
# 4     TV Show          46        Serdar Akar
# ...       ...         ...                ...
# 4803    Movie  Zombieland    Ruben Fleischer
# 4804    Movie         Zoo       Shlok Sharma
# 4805    Movie        Zoom       Peter Hewitt
# 4806    Movie        Zozo        Josef Fares
# 4807    Movie      Zubaan        Mozez Singh
#
#                                                    cast  \
# 0     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 1     Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 2     Elijah Wood, John C. Reilly, Jennifer Connelly...
# 3     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# 4     Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...
# ...                                                 ...
# ...

# %%
horr_count = 0
for i in range(len(df["listed_in"])):
    genere = df["listed_in"][i]
    for j in range(len(genere)):
        if genere[j] == "H" and genere[j + 1] == "o" and genere[j + 2] == "r":
            horr_count += 1
            df["listed_in"][i] = "Horror"
horr_count
# Out:
# <ipython-input-33-2f68840c6cf6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["listed_in"][i] = "Horror"
# 308

# %%
Drama_count = 0
for i in range(len(df["listed_in"])):
    genere = df["listed_in"][i]
    for j in range(len(genere)):
        if genere[j] == "D" and genere[j + 1] == "r" and genere[j + 2] == "a":
            Drama_count += 1
            df["listed_in"][i] = "Drama"
            
Drama_count
# Out:
# <ipython-input-34-0d9af31521eb>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["listed_in"][i] = "Drama"
# 2082

# %%
comedy_count = 0
for i in range(len(df["listed_in"])):
    genere = df["listed_in"][i]
    for j in range(len(genere)):
        if genere[j] == "C" and genere[j + 1] == "o" and genere[j + 2] == "m":
            comedy_count += 1
            df["listed_in"][i] = "Comedy"
comedy_count
# Out:
# <ipython-input-35-faec9537ed2d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["listed_in"][i] = "Comedy"
# 1257

# %%
Action_count = 0
for i in range(len(df["listed_in"])):
    genere = df["listed_in"][i]
    for j in range(len(genere)):
        if genere[j] == "A" and genere[j + 1] == "c" and genere[j + 2] == "t":
            Action_count += 1
            df["listed_in"][i] = "Action"
            
Action_count
# Out:
# <ipython-input-36-58e9fa51cda9>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["listed_in"][i] = "Action"
# 369

# %%
Documentation_count = 0
for i in range(len(df["listed_in"])):
    genere = df["listed_in"][i]
    for j in range(len(genere)):
        if genere[j] == "D" and genere[j + 1] == "o" and genere[j + 2] == "c":
            Documentation_count += 1
            df["listed_in"][i] = "Documentation"
Documentation_count
# Out:
# <ipython-input-37-eaf112817c1a>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["listed_in"][i] = "Documentation"
# 373

# %%
Anime_count = 0
for i in range(len(df["listed_in"])):
    genere = df["listed_in"][i]
    for j in range(len(genere)):
        if genere[j] == "A" and genere[j + 1] == "n" and genere[j + 2] == "i":
            Anime_count += 1
            df["listed_in"][i] = "Anime"
Anime_count
# Out:
# <ipython-input-38-ef8f6e30e138>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["listed_in"][i] = "Anime"
# 26

# %%
Children_family_count = 0
for i in range(len(df["listed_in"])):
    genere = df["listed_in"][i]
    for j in range(len(genere)):
        if genere[j] == "C" and genere[j + 1] == "h" and genere[j + 2] == "i":
            Children_family_count += 1
            df["listed_in"][i] = "Children & Family Movies"
Children_family_count
# Out:
# <ipython-input-39-2087a912184e>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["listed_in"][i] = "Children & Family Movies"
# 152

# %%
International_count = 0
for i in range(len(df["listed_in"])):
    genere = df["listed_in"][i]
    for j in range(len(genere)):
        if genere[j] == "I" and genere[j + 1] == "n" and genere[j + 2] == "t":
            International_count += 1
            df["listed_in"][i] = "International Movies"
International_count
# Out:
# <ipython-input-40-73eef073c41b>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["listed_in"][i] = "International Movies"
# 122

# %%
Independent_count = 0
for i in range(len(df["listed_in"])):
    genere = df["listed_in"][i]
    for j in range(len(genere)):
        if genere[j] == "I" and genere[j + 1] == "n" and genere[j + 2] == "d":
            Independent_count += 1
            df["listed_in"][i] = "Independent Movies"
Independent_count
# Out:
# <ipython-input-41-b9352e36edfb>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["listed_in"][i] = "Independent Movies"
# 17

# %%
Music_count = 0
for i in range(len(df["listed_in"])):
    genere = df["listed_in"][i]
    for j in range(len(genere)):
        if genere[j] == "M" and genere[j + 1] == "u" and genere[j + 2] == "s":
            Music_count += 1
            df["listed_in"][i] = "Music"
Music_count
# Out:
# <ipython-input-42-f308d0a505fa>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["listed_in"][i] = "Music"
# 18

# %%
Thriller_count = 0
for i in range(len(df["listed_in"])):
    genere = df["listed_in"][i]
    for j in range(len(genere)):
        if genere[j] == "T" and genere[j + 1] == "h" and genere[j + 2] == "r":
            Thriller_count += 1
            df["listed_in"][i] = "Thrillers"
Thriller_count
# Out:
# <ipython-input-43-31acbd74ff28>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["listed_in"][i] = "Thrillers"
# 61

# %%
Scify_count = 0
for i in range(len(df["listed_in"])):
    genere = df["listed_in"][i]
    for j in range(len(genere)):
        if genere[j] == "S" and genere[j + 1] == "c" and genere[j + 2] == "i":
            Scify_count += 1
            df["listed_in"][i] = "Scify"
Scify_count
# Out:
# <ipython-input-44-38311d013944>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["listed_in"][i] = "Scify"
# 1

# %%
for i in range(len(df["listed_in"])):
    if df["listed_in"][i] == "Scify":
       pass
    elif df["listed_in"][i] == "Thrillers":
       pass
    elif df["listed_in"][i] == "Action":
        pass
    elif df["listed_in"][i] == "Independent Movies":
       pass
    elif df["listed_in"][i] ==  "International Movies":
       pass
    elif df["listed_in"][i] == "Children & Family Movies":
       pass
    elif df["listed_in"][i] == "Anime":
       pass
    elif df["listed_in"][i] == "Documentation":
       pass
    elif df["listed_in"][i] == "Drama":
       pass
    elif df["listed_in"][i] == "Music":
       pass
    elif df["listed_in"][i] == "Comedy":
       pass
    elif df["listed_in"][i] == "Scify":
       pass
    elif df["listed_in"][i] == "Horror":
       pass
    else:
       df["listed_in"][i] == "Other Movies"

# %%
for i in range(len(df["listed_in"])):
    if df["listed_in"][i] == "Scify":
       df["listed_in"][i] = 11
    elif df["listed_in"][i] == "Thrillers":
      df["listed_in"][i] = 10
    elif df["listed_in"][i] == "Action":
       df["listed_in"][i] = 3
    elif df["listed_in"][i] == "Independent Movies":
       df["listed_in"][i] = 8
    elif df["listed_in"][i] ==  "International Movies":
       df["listed_in"][i] = 7
    elif df["listed_in"][i] == "Children & Family Movies":
       df["listed_in"][i] = 6
    elif df["listed_in"][i] == "Anime":
       df["listed_in"][i] = 5
    elif df["listed_in"][i] == "Documentation":
       df["listed_in"][i] = 4
    elif df["listed_in"][i] == "Drama":
       df["listed_in"][i] = 1
    elif df["listed_in"][i] == "Music":
       df["listed_in"][i] = 9
    elif df["listed_in"][i] == "Comedy":
       df["listed_in"][i] = 2
    elif df["listed_in"][i] == "Horror":
       df["listed_in"][i] = 0 
    elif df["listed_in"][i] == "Other Movies":
       df["listed_in"][i] = 12
# Out:
# <ipython-input-46-7b114d389012>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["listed_in"][i] = 1
# <ipython-input-46-7b114d389012>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["listed_in"][i] = 0
# <ipython-input-46-7b114d389012>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["listed_in"][i] = 3
# <ipython-input-46-7b114d389012>:17: SettingWithCopyWarning:
# ...

# %%
for i in range(len(df["type"])):
    if df["type"][i] == "Movie":
        df["type"][i] = 0
    elif df["type"][i] == "TV Show":
        df["type"][i] = 1
# Out:
# <ipython-input-47-05c943585d88>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["type"][i] = 0
# <ipython-input-47-05c943585d88>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["type"][i] = 1

# %%
data = {"Scify":Scify_count , "Thr":Thriller_count , "Action":Action_count , 
        "Ind":Independent_count ,"Inter":International_count ,
       "Child":Children_family_count , "Anie":Anime_count , "Docu":Documentation_count , 
       "Dra":Drama_count , "Mus":Music_count , "Come":comedy_count , "Horr":horr_count }

values = list(data.values())
keys = list(data.keys())

plt.bar(keys , values)
# Out:
# <BarContainer object of 12 artists>

# %%
df
# Out:
#      type       title           director  \
# 0       0        7:19  Jorge Michel Grau
# 1       0       23:59       Gilbert Chan
# 2       0           9        Shane Acker
# 3       0          21     Robert Luketic
# 4       1          46        Serdar Akar
# ...   ...         ...                ...
# 4803    0  Zombieland    Ruben Fleischer
# 4804    0         Zoo       Shlok Sharma
# 4805    0        Zoom       Peter Hewitt
# 4806    0        Zozo        Josef Fares
# 4807    0      Zubaan        Mozez Singh
#
#                                                    cast  \
# 0     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 1     Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 2     Elijah Wood, John C. Reilly, Jennifer Connelly...
# 3     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# 4     Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...
# ...                                                 ...
# 4803  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...
# ...

# %%
df
# Out:
#      type       title           director  \
# 0       0        7:19  Jorge Michel Grau
# 1       0       23:59       Gilbert Chan
# 2       0           9        Shane Acker
# 3       0          21     Robert Luketic
# 4       1          46        Serdar Akar
# ...   ...         ...                ...
# 4803    0  Zombieland    Ruben Fleischer
# 4804    0         Zoo       Shlok Sharma
# 4805    0        Zoom       Peter Hewitt
# 4806    0        Zozo        Josef Fares
# 4807    0      Zubaan        Mozez Singh
#
#                                                    cast  \
# 0     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 1     Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 2     Elijah Wood, John C. Reilly, Jennifer Connelly...
# 3     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# 4     Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...
# ...                                                 ...
# 4803  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...
# ...

# %%
from sklearn.model_selection import KFold
from sklearn.ensemble import RandomForestClassifier
kf =KFold(n_splits = 5)

from sklearn.model_selection import cross_val_score
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split

# %%
df_for_model = df.drop(columns = ["title" , "country", "date_added", "release_year", "rating", "description", "duration"])

# %%
df_for_model
# Out:
#      type           director  \
# 0       0  Jorge Michel Grau
# 1       0       Gilbert Chan
# 2       0        Shane Acker
# 3       0     Robert Luketic
# 4       1        Serdar Akar
# ...   ...                ...
# 4803    0    Ruben Fleischer
# 4804    0       Shlok Sharma
# 4805    0       Peter Hewitt
# 4806    0        Josef Fares
# 4807    0        Mozez Singh
#
#                                                    cast listed_in
# 0     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         1
# 1     Tedd Chan, Stella Chung, Henley Hii, Lawrence ...         0
# 2     Elijah Wood, John C. Reilly, Jennifer Connelly...         3
# 3     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...         1
# 4     Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...         1
# ...                                                 ...       ...
# 4803  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...         0
# 4804  Shashank Arora, Shweta Tripathi, Rahul Kumar, ...         1
# ...

# %%
x = df_for_model.drop(columns = ["listed_in"])

# %%
x
# Out:
#      type           director  \
# 0       0  Jorge Michel Grau
# 1       0       Gilbert Chan
# 2       0        Shane Acker
# 3       0     Robert Luketic
# 4       1        Serdar Akar
# ...   ...                ...
# 4803    0    Ruben Fleischer
# 4804    0       Shlok Sharma
# 4805    0       Peter Hewitt
# 4806    0        Josef Fares
# 4807    0        Mozez Singh
#
#                                                    cast
# 0     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 1     Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 2     Elijah Wood, John C. Reilly, Jennifer Connelly...
# 3     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# 4     Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...
# ...                                                 ...
# 4803  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...
# 4804  Shashank Arora, Shweta Tripathi, Rahul Kumar, ...
# 4805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
# ...

# %%
y = df_for_model["listed_in"]

# %%
y
# Out:
# 0       1
# 1       0
# 2       3
# 3       1
# 4       1
#        ..
# 4803    0
# 4804    1
# 4805    2
# 4806    1
# 4807    1
# Name: listed_in, Length: 4808, dtype: object
